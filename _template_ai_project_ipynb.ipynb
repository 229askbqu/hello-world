# %% [markdown]
# <a href="https://colab.research.google.com/github/229askbqu/hello-world/blob/main/_template_ai_project_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
